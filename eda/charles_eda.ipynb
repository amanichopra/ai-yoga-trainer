# %%
import os
import pandas as pd
import warnings
import seaborn as sns

warnings.filterwarnings("ignore")

from google.colab import drive


drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
GDRIVE_DATA_ROOT = 'drive/MyDrive/AML_final_proj/Yoga-82'

# %%
train_data = pd.read_csv(os.path.join(GDRIVE_DATA_ROOT, 'yoga_train.txt'), header=None)
test_data = pd.read_csv(os.path.join(GDRIVE_DATA_ROOT, 'yoga_test.txt'), header=None)

# %%
train_data.rename(columns={0: 'pose_and_file', 1: 'lbl_class_6', 2: 'lbl_class_20', 3: 'lbl_class_82'}, inplace=True)
train_data[['pose_name', 'file_name']] = train_data['pose_and_file'].str.split('/', 1, expand=True)
train_data.drop(columns=['pose_and_file'], inplace=True)
train_data.head()
# Out:
#    lbl_class_6  lbl_class_20  lbl_class_82           pose_name file_name
# 0            1             8             0  Akarna_Dhanurasana    64.jpg
# 1            1             8             0  Akarna_Dhanurasana   229.jpg
# 2            1             8             0  Akarna_Dhanurasana   128.jpg
# 3            1             8             0  Akarna_Dhanurasana   145.jpg
# 4            1             8             0  Akarna_Dhanurasana    47.jpg

# %%
test_data.rename(columns={0: 'pose_and_file', 1: 'lbl_class_6', 2: 'lbl_class_20', 3: 'lbl_class_82'}, inplace=True)
test_data[['pose_name', 'file_name']] = test_data['pose_and_file'].str.split('/', 1, expand=True)
test_data.drop(columns=['pose_and_file'], inplace=True)
test_data.head()
# Out:
#    lbl_class_6  lbl_class_20  lbl_class_82           pose_name file_name
# 0            1             8             0  Akarna_Dhanurasana    16.jpg
# 1            1             8             0  Akarna_Dhanurasana    95.jpg
# 2            1             8             0  Akarna_Dhanurasana   263.jpg
# 3            1             8             0  Akarna_Dhanurasana   110.jpg
# 4            1             8             0  Akarna_Dhanurasana    21.jpg

# %%
train_X = train_data.drop(columns=['pose_name'])
train_y = train_data['pose_name']

# %%
sns.set(font_scale=1.25)
plt.figure(figsize=(20, 12))  # Adjust figure size if needed
sns.barplot(x=train_data['pose_name'].value_counts().index, y=train_data['pose_name'].value_counts().values)
plt.xlabel('Yoga Pose Name')
plt.ylabel('Number of samples')
plt.title('Target Class Distribution')
plt.xticks(rotation=90)  # Rotate x-axis labels if needed for readability
plt.show()

# %%
train_data.isna().sum(axis=0)
# Out:
# lbl_class_6     0
# lbl_class_20    0
# lbl_class_82    0
# pose_name       0
# file_name       0
# dtype: int64

# %%
test_data.isna().sum(axis=0)
# Out:
# lbl_class_6     0
# lbl_class_20    0
# lbl_class_82    0
# pose_name       0
# file_name       0
# dtype: int64

# %%
train_data.shape
# Out:
# (20994, 5)

# %%
test_data.shape
# Out:
# (7456, 5)
